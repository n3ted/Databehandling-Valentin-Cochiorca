# %%
import pandas as pd

# %%
column_values = [f'Column{i}' for i in range(1, 5)]
index_values = [chr(i) for i in range(65, 72)]

df = pd.DataFrame([[f"{ind}{col}" for col in range(1,5)] for ind in index_values],
                  index=index_values, columns=column_values)

df
# Out:
#   Column1 Column2 Column3 Column4
# A      A1      A2      A3      A4
# B      B1      B2      B3      B4
# C      C1      C2      C3      C4
# D      D1      D2      D3      D4
# E      E1      E2      E3      E4
# F      F1      F2      F3      F4
# G      G1      G2      G3      G4

# %% [markdown]
# # Uppdate cells using loc or iloc
#
# One or multiple cells can be set to a new value using loc or iloc.
#
# - df.iloc[:] = 0 Setts all cell to 0
# - df.iloc[0,0] = 0 Sets cells[0,0] to 0

# %%
copy = df.copy()
copy.iloc[1,2] = 'XX'
copy.iloc[0, :] = 'YY'
copy.loc[['C','E','G'], ['Column2', 'Column3']] = 'ZZ'
copy.iloc[:2, :2] = copy.iloc[-2:, -2:] + 'ZZ'
copy.iloc[:, :] = 0
copy
# Out:
#   Column1 Column2 Column3 Column4
# A       0       0       0       0
# B       0       0       0       0
# C       0       0       0       0
# D       0       0       0       0
# E       0       0       0       0
# F       0       0       0       0
# G       0       0       0       0

# %% [markdown]
# # Adding row or columns
#
# Rows and columns can be added using loc(but not iloc)

# %%
copy = df.copy()
copy.loc['H'] = ['H1', 'H2', 'H3', 'H4']
copy.loc[:, 'Column5'] = 0
copy.loc[:, 'Column6'] = copy.loc[:, 'Column1'] + '-' + copy.loc[:, 'Column3']
copy['Column7'] = copy['Column1'] + '-' + copy['Column6']
copy.loc['I', ['Column3', 'Column6']] = 0
copy.loc['J', 'new_column'] = 'Hello'
copy
# Out:
#   Column1 Column2 Column3 Column4  Column5 Column6   Column7 new_column
# A      A1      A2      A3      A4      0.0   A1-A3  A1-A1-A3        nan
# B      B1      B2      B3      B4      0.0   B1-B3  B1-B1-B3        nan
# C      C1      C2      C3      C4      0.0   C1-C3  C1-C1-C3        nan
# D      D1      D2      D3      D4      0.0   D1-D3  D1-D1-D3        nan
# E      E1      E2      E3      E4      0.0   E1-E3  E1-E1-E3        nan
# F      F1      F2      F3      F4      0.0   F1-F3  F1-F1-F3        nan
# G      G1      G2      G3      G4      0.0   G1-G3  G1-G1-G3        nan
# H      H1      H2      H3      H4      0.0   H1-H3  H1-H1-H3        nan
# I     NaN     NaN       0     NaN      NaN       0       NaN        nan
# J     NaN     NaN     NaN     NaN      NaN     NaN       NaN      Hello

# %% [markdown]
# # Renaming columns and idexes

# %%
copy = df.copy()
copy.columns = ['A', 'B', 'C', 'D']
copy.index = [0, 1, 2, 3, 4, 5, 6]
copy.rename(columns={'B': 'Column B', 'D': 'Fredrik'}, inplace= True)
copy.rename(index={4 : 'Four'}, inplace=True)
copy
# Out:
#        A Column B   C Fredrik
# 0     A1       A2  A3      A4
# 1     B1       B2  B3      B4
# 2     C1       C2  C3      C4
# 3     D1       D2  D3      D4
# Four  E1       E2  E3      E4
# 5     F1       F2  F3      F4
# 6     G1       G2  G3      G4

# %% [markdown]
# # Delete rows and columns

# %%
copy = df.copy()
copy.drop(index=['B', 'F'], columns='Column3', inplace=True) # inplace=True to update "copy"
copy
# Out:
#   Column1 Column2 Column4
# A      A1      A2      A4
# C      C1      C2      C4
# D      D1      D2      D4
# E      E1      E2      E4
# G      G1      G2      G4
